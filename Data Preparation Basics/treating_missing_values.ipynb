# %% [markdown]
# # Data Preparation Basics

# %% [markdown]
# ## 2. Treating missing values

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %% [markdown]
# ### Figuring out what data is missing

# %%
missing = np.nan

series_obj = Series(['row 1', 'row 2', missing, 'row 4', 'row 5', missing, 'row 7', missing, 'row 9'])
series_obj
# Out:
# 0    row 1
# 1    row 2
# 2      NaN
# 3    row 4
# 4    row 5
# 5      NaN
# 6    row 7
# 7      NaN
# 8    row 9
# dtype: object

# %%
series_obj.isnull()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# 5     True
# 6    False
# 7     True
# 8    False
# dtype: bool

# %% [markdown]
# ### Filling in for missing values

# %%
np.random.seed(24)
DF_obj = DataFrame(np.random.rand(36).reshape(6, 6))
DF_obj
# Out:
#           0         1         2         3         4         5
# 0  0.960017  0.699512  0.999867  0.220067  0.361056  0.739841
# 1  0.996456  0.316347  0.136545  0.383980  0.320519  0.366415
# 2  0.709652  0.900142  0.534115  0.247294  0.671807  0.561729
# 3  0.542560  0.893448  0.842780  0.306013  0.631170  0.680239
# 4  0.970428  0.893567  0.942426  0.642225  0.614648  0.227683
# 5  0.486032  0.807219  0.844220  0.534681  0.757798  0.499677

# %%
DF_obj.loc[3:5, 0] = missing
DF_obj.loc[1:4, 5] = missing
DF_obj
# Out:
#           0         1         2         3         4         5
# 0  0.960017  0.699512  0.999867  0.220067  0.361056  0.739841
# 1  0.996456  0.316347  0.136545  0.383980  0.320519       NaN
# 2  0.709652  0.900142  0.534115  0.247294  0.671807       NaN
# 3       NaN  0.893448  0.842780  0.306013  0.631170       NaN
# 4       NaN  0.893567  0.942426  0.642225  0.614648       NaN
# 5       NaN  0.807219  0.844220  0.534681  0.757798  0.499677

# %%
filled_DF = DF_obj.fillna(1)
filled_DF
# Out:
#           0         1         2         3         4         5
# 0  0.960017  0.699512  0.999867  0.220067  0.361056  0.739841
# 1  0.996456  0.316347  0.136545  0.383980  0.320519  1.000000
# 2  0.709652  0.900142  0.534115  0.247294  0.671807  1.000000
# 3  1.000000  0.893448  0.842780  0.306013  0.631170  1.000000
# 4  1.000000  0.893567  0.942426  0.642225  0.614648  1.000000
# 5  1.000000  0.807219  0.844220  0.534681  0.757798  0.499677

# %%
filled_DF = DF_obj.fillna({0:0.1, 5:1.25})
filled_DF
# Out:
#           0         1         2         3         4         5
# 0  0.960017  0.699512  0.999867  0.220067  0.361056  0.739841
# 1  0.996456  0.316347  0.136545  0.383980  0.320519  1.250000
# 2  0.709652  0.900142  0.534115  0.247294  0.671807  1.250000
# 3  0.100000  0.893448  0.842780  0.306013  0.631170  1.250000
# 4  0.100000  0.893567  0.942426  0.642225  0.614648  1.250000
# 5  0.100000  0.807219  0.844220  0.534681  0.757798  0.499677

# %%
# Using last non-null element in column
fill_DF = DF_obj.fillna(method='ffill')
fill_DF
# Out:
#           0         1         2         3         4         5
# 0  0.960017  0.699512  0.999867  0.220067  0.361056  0.739841
# 1  0.996456  0.316347  0.136545  0.383980  0.320519  0.739841
# 2  0.709652  0.900142  0.534115  0.247294  0.671807  0.739841
# 3  0.709652  0.893448  0.842780  0.306013  0.631170  0.739841
# 4  0.709652  0.893567  0.942426  0.642225  0.614648  0.739841
# 5  0.709652  0.807219  0.844220  0.534681  0.757798  0.499677

# %% [markdown]
# ### Counting missing values

# %%
np.random.seed(24)
DF_obj = DataFrame(np.random.rand(36).reshape(6, 6))
DF_obj.loc[3:5, 0] = missing
DF_obj.loc[1:4, 5] = missing
DF_obj
# Out:
#           0         1         2         3         4         5
# 0  0.960017  0.699512  0.999867  0.220067  0.361056  0.739841
# 1  0.996456  0.316347  0.136545  0.383980  0.320519       NaN
# 2  0.709652  0.900142  0.534115  0.247294  0.671807       NaN
# 3       NaN  0.893448  0.842780  0.306013  0.631170       NaN
# 4       NaN  0.893567  0.942426  0.642225  0.614648       NaN
# 5       NaN  0.807219  0.844220  0.534681  0.757798  0.499677

# %%
DF_obj.isnull().sum()
# Out:
# 0    3
# 1    0
# 2    0
# 3    0
# 4    0
# 5    4
# dtype: int64

# %% [markdown]
# ### Filtering out missing values

# %%
# Dropping the row
DF_no_NaN = DF_obj.dropna()
DF_no_NaN
# Out:
#           0         1         2         3         4         5
# 0  0.960017  0.699512  0.999867  0.220067  0.361056  0.739841

# %%
# Dropping the column
DF_no_NaN = DF_obj.dropna(axis=1)
DF_no_NaN
# Out:
#           1         2         3         4
# 0  0.699512  0.999867  0.220067  0.361056
# 1  0.316347  0.136545  0.383980  0.320519
# 2  0.900142  0.534115  0.247294  0.671807
# 3  0.893448  0.842780  0.306013  0.631170
# 4  0.893567  0.942426  0.642225  0.614648
# 5  0.807219  0.844220  0.534681  0.757798
